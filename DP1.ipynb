# %% [markdown]
# # Ex1 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
# Copy file from GitHub into DBFS
dbutils.fs.cp(
    "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",
    "dbfs:/FileStore/tables/chipotle.tsv"
)
# Out:
# Out[1]: True

# %%
url = "dbfs:/FileStore/tables/chipotle.tsv"

df= spark.read.format('csv') \
    .option('inferSchema','True')\
        .option('header','True')\
            .option('delimiter','\t')\
                .load(url)

display(df)
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>quantity</th><th>item_name</th><th>choice_description</th><th>item_price</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>Chips and Fresh Tomato Salsa</td><td>NULL</td><td>$2.39 </td></tr><tr><td>1</td><td>1</td><td>Izze</td><td>[Clementine]</td><td>$3.39 </td></tr><tr><td>1</td><td>1</td><td>Nantucket Nectar</td><td>[Apple]</td><td>$3.39 </td></tr><tr><td>1</td><td>1</td><td>Chips and Tomatillo-Green Chili Salsa</td><td>NULL</td><td>$2.39 </td></tr><tr><td>2</td><td>2</td><td>Chicken Bowl</td><td>[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]</td><td>$16.98 </td></tr><tr><td>3</td><td>1</td><td>Chicken Bowl</td><td>[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]</td><td>$10.98 </td></tr><tr><td>3</td><td>1</td><td>Side of Chips</td><td>NULL</td><td>$1.69 </td></tr><tr><td>4</td><td>1</td><td>Steak Burrito</td><td>[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]</td><td>$11.75 </td></tr><tr><td>4</td><td>1</td><td>Steak Soft Tacos</td><td>[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]</td><td>$9.25 </td></tr><tr><td>5</td><td>1</td><td>Steak Burrito</td><td>[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]</td><td>$9.25 </td></tr><tr><td>5</td><td>1</td><td>Chips and Guacamole</td><td>NULL</td><td>$4.45 </td></tr><tr><td>6</td><td>1</td><td>Chicken Crispy Tacos</td><td>[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]</td><td>$8.75 </td></tr><tr><td>6</td><td>1</td><td>Chicken Soft Tacos</td><td>[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]</td><td>$8.75 </td></tr><tr><td>7</td><td>1</td><td>Chicken Bowl</td><td>[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]</td><td>$11.25 </td></tr><tr><td>7</td><td>1</td><td>Chips and Guacamole</td><td>NULL</td><td>$4.45 </td></tr><tr><td>8</td><td>1</td><td>Chips and Tomatillo-Green Chili Salsa</td><td>NULL</td><td>$2.39 </td></tr><tr><td>8</td><td>1</td><td>Chicken Burrito</td><td>[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]</td><td>$8.49 </td></tr><tr><td>9</td><td>1</td><td>Chicken Burrito</td><td>[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]</td><td>$8.49 </td></tr><tr><td>9</td><td>2</td><td>Canned Soda</td><td>[Sprite]</td><td>$2.18 </td></tr><tr><td>10</td><td>1</td><td>Chicken Bowl</td><td>[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]</td><td>$8.75 </td></tr><tr><td>10</td><td>1</td><td>Chips and Guacamole</td><td>NULL</td><td>$4.45 </td></tr><tr><td>11</td><td>1</td><td>Barbacoa Burrito</td><td>[[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Rice, Cheese, Sour Cream, Lettuce]]</td><td>$8.99 </td></tr><tr><td>11</td><td>1</td><td>Nantucket Nectar</td><td>[Pomegranate Cherry]</td><td>$3.39 </td></tr><tr><td>12</td><td>1</td><td>Chicken Burrito</td><td>[[Tomatillo-Green Chili Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Pinto Beans, Rice, Cheese, Sour Cream, Guacamole, Lettuce]]</td><td>$10.98 </td></tr><tr><td>12</td><td>1</td><td>Izze</td><td>[Grapefruit]</td><td>$3.39 </td></tr><tr><td>13</td><td>1</td><td>Chips and Fresh Tomato Salsa</td><td>NULL</td><td>$2.39 </td></tr><tr><td>13</td><td>1</td><td>Chicken Bowl</td><td>[Roasted Chili Corn Salsa (Medium), [Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]</td><td>$8.49 </td></tr><tr><td>14</td><td>1</td><td>Carnitas Burrito</td><td>[[Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans, Rice, Sour Cream, Lettuce]]</td><td>$8.99 </td></tr><tr><td>14</td><td>1</td><td>Canned Soda</td><td>[Dr. Pepper]</td><td>$1.09 </t ...
# root
#  |-- order_id: integer (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- item_name: string (nullable = true)
#  |-- choice_description: string (nullable = true)
#  |-- item_price: string (nullable = true)

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo=df

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.show(10)
# Out:
# +--------+--------+--------------------+--------------------+----------+
# |order_id|quantity|           item_name|  choice_description|item_price|
# +--------+--------+--------------------+--------------------+----------+
# |       1|       1|Chips and Fresh T...|                NULL|    $2.39 |
# |       1|       1|                Izze|        [Clementine]|    $3.39 |
# |       1|       1|    Nantucket Nectar|             [Apple]|    $3.39 |
# |       1|       1|Chips and Tomatil...|                NULL|    $2.39 |
# |       2|       2|        Chicken Bowl|[Tomatillo-Red Ch...|   $16.98 |
# |       3|       1|        Chicken Bowl|[Fresh Tomato Sal...|   $10.98 |
# |       3|       1|       Side of Chips|                NULL|    $1.69 |
# |       4|       1|       Steak Burrito|[Tomatillo Red Ch...|   $11.75 |
# |       4|       1|    Steak Soft Tacos|[Tomatillo Green ...|    $9.25 |
# |       5|       1|       Steak Burrito|[Fresh Tomato Sal...|    $9.25 |
# +--------+--------+--------------------+--------------------+----------+
# only showing top 10 rows

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.count()
# Out:
# Out[12]: 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# Out[14]: 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Out[15]: ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
from pyspark.sql.functions import *
df_indexed=df.withColumn("row_index",monotonically_increasing_id())
display(df_indexed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>quantity</th><th>item_name</th><th>choice_description</th><th>item_price</th><th>row_index</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>Chips and Fresh Tomato Salsa</td><td>NULL</td><td>$2.39 </td><td>0</td></tr><tr><td>1</td><td>1</td><td>Izze</td><td>[Clementine]</td><td>$3.39 </td><td>1</td></tr><tr><td>1</td><td>1</td><td>Nantucket Nectar</td><td>[Apple]</td><td>$3.39 </td><td>2</td></tr><tr><td>1</td><td>1</td><td>Chips and Tomatillo-Green Chili Salsa</td><td>NULL</td><td>$2.39 </td><td>3</td></tr><tr><td>2</td><td>2</td><td>Chicken Bowl</td><td>[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]
[Pinto Beans, Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]</td>< ...

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
most_ordered=df.groupBy("item_name") \
    .agg(sum("quantity").alias("Total_Ordered")) \
        .orderBy(col("Total_Ordered").desc())
most_ordered.show(1)
# Out:
# +------------+-------------+
# |   item_name|Total_Ordered|
# +------------+-------------+
# |Chicken Bowl|          761|
# +------------+-------------+
# only showing top 1 row

# %% [markdown]
# ### Step 10. What was the most ordered item in the choice_description column?

# %%
most_ordered_df=df.groupBy("choice_description")\
    .agg(sum(col("quantity")).alias("Total_Ordered"))\
        .orderBy(col("Total_Ordered").desc()).limit(1)
display(most_ordered_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>choice_description</th><th>Total_Ordered</th></tr></thead><tbody><tr><td>NULL</td><td>1382</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 11. How many items were orderd in total?

# %%
df.agg(sum("quantity")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(quantity)</th></tr></thead><tbody><tr><td>4972</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 12. Turn the item price into a float

# %%
df_clean=df.withColumn("item_price",
                       regexp_replace(col("item_price"),"[$]","").cast('double'))
df_clean.printSchema()
df_clean.show(5)
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- item_name: string (nullable = true)
#  |-- choice_description: string (nullable = true)
#  |-- item_price: double (nullable = true)
#
# +--------+--------+--------------------+--------------------+----------+
# |order_id|quantity|           item_name|  choice_description|item_price|
# +--------+--------+--------------------+--------------------+----------+
# |       1|       1|Chips and Fresh T...|                NULL|      2.39|
# |       1|       1|                Izze|        [Clementine]|      3.39|
# |       1|       1|    Nantucket Nectar|             [Apple]|      3.39|
# |       1|       1|Chips and Tomatil...|                NULL|      2.39|
# |       2|       2|        Chicken Bowl|[Tomatillo-Red Ch...|     16.98|
# +--------+--------+--------------------+--------------------+----------+
# only showing top 5 rows

# %% [markdown]
# #### Step 13. Check the item price type

# %%
df_clean.select("item_price").dtypes
# Out:
# Out[39]: [('item_price', 'double')]

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
df_clean.withColumn("Revenue",col('quantity')*col('item_price'))\
.agg(sum("Revenue").alias("Total Revenue")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total Revenue</th></tr></thead><tbody><tr><td>39237.020000000055</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
df.select(countDistinct("order_id").alias("Total Orders")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total Orders</th></tr></thead><tbody><tr><td>1834</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
order_revenue = df_clean.groupBy("order_id").agg(sum(col("item_price")*col("quantity")).alias("order_revenue"))
order_revenue.agg(avg("order_revenue").alias("Avg_Order_Value")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Avg_Order_Value</th></tr></thead><tbody><tr><td>21.394231188658736</td></tr></tbody></table></div>

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
df.select(countDistinct("item_name")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCT item_name)</th></tr></thead><tbody><tr><td>50</td></tr></tbody></table></div>
